# %% [markdown]
# ## Imports

# %%
#EDA Basics
import pandas as pd
import numpy as np

#Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

#Removing warnings 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading CSV - EDA

# %%
file_path = "/Users/kellyjara/Desktop/Job_Postings/Data/gsearch_jobs.csv"

# %%
csv = pd.read_csv(file_path)

# %%
df = pd.DataFrame(csv)
df.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0                                       Data Analyst
# 1           1      1       Entry Level - Business Data Analyst (Remote)
# 2           2      2                            Data Analyst/Researcher
# 3           3      3  Data analyst/AI expert to help build a website...
# 4           4      4                                       Data Analyst
#
#                        company_name            location  \
# 0                      Cisco Meraki           Anywhere
# 1                  Midwest Staffing           Anywhere
# 2                        Amyx, Inc.    United States
# 3                            Upwork           Anywhere
# 4  Bank Street College of Education    United States
#
#                                                  via  \
# 0                                       via LinkedIn
# 1                                       via LinkedIn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32505 entries, 0 to 32504
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           32505 non-null  int64
#  1   index                32505 non-null  int64
#  2   title                32505 non-null  object
#  3   company_name         32505 non-null  object
#  4   location             32483 non-null  object
#  5   via                  32496 non-null  object
#  6   description          32505 non-null  object
#  7   extensions           32505 non-null  object
#  8   job_id               32505 non-null  object
#  9   thumbnail            17863 non-null  object
#  10  posted_at            32505 non-null  object
#  11  schedule_type        32328 non-null  object
#  12  work_from_home       14477 non-null  object
#  13  salary               5907 non-null   object
#  14  search_term          32505 non-null  object
# ...

# %%
df = df.drop(columns = 'Unnamed: 0', axis = 1)

# %%
# Have a significant amount of null/nan values due to salary columns not being properly filled out.

# %%
df.head()
# Out:
#    index                                              title  \
# 0      0                                       Data Analyst
# 1      1       Entry Level - Business Data Analyst (Remote)
# 2      2                            Data Analyst/Researcher
# 3      3  Data analyst/AI expert to help build a website...
# 4      4                                       Data Analyst
#
#                        company_name            location  \
# 0                      Cisco Meraki           Anywhere
# 1                  Midwest Staffing           Anywhere
# 2                        Amyx, Inc.    United States
# 3                            Upwork           Anywhere
# 4  Bank Street College of Education    United States
#
#                                                  via  \
# 0                                       via LinkedIn
# 1                                       via LinkedIn
# 2                                         via Indeed
# 3                                         via Upwork
# ...

# %%
first_position = df['description'].iloc[0]
first_position
# Out:
# "As the leader in cloud-managed IT, Cisco Meraki connects passionate people to their mission by simplifying the digital workplace. Our impact is driven by the innovative, purposeful, and vibrant people who make up our inclusive community. When technology is intuitive, our customers can focus on what matters.\n\nWe are building a network of future Merakians who are excited by our mission & culture... and want to make an impact in their next role. We would like to hear from you if you are interested in being considered for future career opportunities with us.\n\nTo be considered for future roles, please submit your resume. When a position is available that matches your background and skill set, we will get in touch with you.\n\nPlease note this job posting is currently not open and is intended to advertise future job opportunities.\n\nThe Data Science team is a growing group that works closely with executives and leaders across the company to support the development of and alignment on
# ...

# %%
# Some descriptions of the position has the salary value stated. 
# Can use NLP to extract that information and create a new salary column 
# Can also take in some key words that can help analysts see what characteristics employers are looking for
# Also look into key skills companies are looking for in an analyst

# %%
first_salary = df['salary_pay'].iloc[0]
first_salary
# Out:
# nan

# %%
first_ext = df['extensions'].iloc[0]
first_ext
# Out:
# "['22 hours ago', 'Work from home', 'Full-time', 'Health insurance', 'Dental insurance', 'Paid time off']"

# %%
# Extension column has information about how long ago the job was posted (not necessary)
# also has what type of position is (wfm, remote, hybrid, etc) and can create new column values 
# can create a benefits column

# %%
df['location'].value_counts()
# Out:
#  Anywhere                 7383
# Anywhere                  7094
#   United States           5008
# United States             3660
#   Oklahoma City, OK        561
#                           ...
#   Somerville, MA             1
# Green, KS                    1
#   Olean, MO                  1
#   Argyle, MO                 1
# Sand Springs, OK             1
# Name: location, Length: 626, dtype: int64

# %%
# can clean up location column by combining duplicate values such as "anywhere" and "united states"
# seeing that they are two values that are repeating
# can create a map to show which cities/states are having larger influxes of hiring analysts.

# %%
df['title'].value_counts()
# Out:
# Data Analyst                                   3804
# Senior Data Analyst                            1078
# Data Analyst II                                 391
# Lead Data Analyst                               329
# Business Data Analyst                           323
#                                                ...
# Google Analytics  Setup                           1
# Data Analyst with Tableau and SQL expertise       1
# Automating a set of excel data analytics          1
# GA4 Analytics Setup                               1
# Lead FP&A Analyst- Remote, US                     1
# Name: title, Length: 12552, dtype: int64

# %%
# Can create a new column that places certain titles within entry, mid or seniors levels.
# This way we can see what key skills/characteristics align with which levels.

# %%
df['thumbnail'].value_counts()
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRy7BDVLI1v0TTiEd_1-A9erQIeLXnbzmstT3FzCrk&s    2561
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiG1XqS45dxlq1jSaWlWdEUmoqOCCoL3sfm_WtrtM&s     489
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTchgwk0qIvqPnMlAcqO5451PRYsMDccWFDcD5pGeE&s     299
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ32hNVts3A-3YRTG8M7WklrOLXQlO1QPu8gzscu6c&s     265
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3NPZVfMWlf1Xobrp_Lh-K5I_QQ6QYxbe8RTgfrJ8&s     177
#                                                                                                      ...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNFjoR5CziT5XNZwQmaoclf_6mzKQbBP62DgZ5724&s       1
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqJC3Qs0WbuDoy5JzJXtxMAMGeT2L7kBngPcTrfec&s       1
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWKy26RbwKSKSJLS3iUBxUtkBAqItB9E9tX3kYuJA&s       1
# ...

# %%
#can remove "thumbnail" column since it does not provide any useful information 
df = df.drop(columns = 'thumbnail', axis = 1)
df.head()
# Out:
#    index                                              title  \
# 0      0                                       Data Analyst
# 1      1       Entry Level - Business Data Analyst (Remote)
# 2      2                            Data Analyst/Researcher
# 3      3  Data analyst/AI expert to help build a website...
# 4      4                                       Data Analyst
#
#                        company_name            location  \
# 0                      Cisco Meraki           Anywhere
# 1                  Midwest Staffing           Anywhere
# 2                        Amyx, Inc.    United States
# 3                            Upwork           Anywhere
# 4  Bank Street College of Education    United States
#
#                                                  via  \
# 0                                       via LinkedIn
# 1                                       via LinkedIn
# 2                                         via Indeed
# 3                                         via Upwork
# ...

# %%
df['job_id'].value_counts()
# Out:
# ...                                                                                                                                                                                                                                                                                                                                        3
# ...                                                                                                                                                                                                                                                                        3
# ...            3
# ...                                                                                                                                                                                                                                                                3
# ...

# %%
# can also remove "job_id" and "descriptive_tokens" from df
df = df.drop(columns=['job_id', 'description_tokens'], axis=1)
df.head()
# Out:
#    index                                              title  \
# 0      0                                       Data Analyst
# 1      1       Entry Level - Business Data Analyst (Remote)
# 2      2                            Data Analyst/Researcher
# 3      3  Data analyst/AI expert to help build a website...
# 4      4                                       Data Analyst
#
#                        company_name            location  \
# 0                      Cisco Meraki           Anywhere
# 1                  Midwest Staffing           Anywhere
# 2                        Amyx, Inc.    United States
# 3                            Upwork           Anywhere
# 4  Bank Street College of Education    United States
#
#                                                  via  \
# 0                                       via LinkedIn
# 1                                       via LinkedIn
# 2                                         via Indeed
# 3                                         via Upwork
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32505 entries, 0 to 32504
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                32505 non-null  int64
#  1   title                32505 non-null  object
#  2   company_name         32505 non-null  object
#  3   location             32483 non-null  object
#  4   via                  32496 non-null  object
#  5   description          32505 non-null  object
#  6   extensions           32505 non-null  object
#  7   posted_at            32505 non-null  object
#  8   schedule_type        32328 non-null  object
#  9   work_from_home       14477 non-null  object
#  10  salary               5907 non-null   object
#  11  search_term          32505 non-null  object
#  12  date_time            32505 non-null  object
#  13  search_location      32505 non-null  object
#  14  commute_time         0 non-null      float64
# ...
